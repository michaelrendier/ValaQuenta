# %% [markdown]
# # Method 3: Sedenion Spectral Relativity Geodesic
#
# **Ainulindale Engine** — Tier udeo_crypto
#
# Cody's method 3 — sigma-face metric geodesic distance e to d. At chance.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../..'))
import importlib.util, math, cmath, numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
plt.rcParams.update({'figure.dpi': 120, 'font.size': 11,
                     'axes.spines.top': False, 'axes.spines.right': False})

def load_maths(tier):
    paths = {7: '../../modules/tier7_cosmos/maths.py',
             8: '../../modules/tier8_sedenion/maths.py',
             9: '../../modules/tier9_chem/maths.py',
             'udeo_crypto': '../../modules/udeo_crypto/UDEO_RSA_DEMO.py'}
    spec = importlib.util.spec_from_file_location(f't{tier}', paths[tier])
    m = importlib.util.module_from_spec(spec); spec.loader.exec_module(m)
    return m

OMEGA_ZS = 0.5671432904097838
D_STAR   = 0.24600
GAP      = OMEGA_ZS - D_STAR * math.log(10)
R_H      = 1.0 / math.sqrt(2.0)
RIEMANN_ZEROS = [14.134725, 21.022040, 25.010858, 30.424876, 32.935062,
                 37.586178, 40.918719, 43.327073, 48.005151, 49.773832]
print("Ainulindale notebook ready.")
# Out:
# Ainulindale notebook ready.

# %%
m = load_maths('udeo_crypto')
result = m.method3_spectral_relativity()
print("Claim:", result['claim'])
print("Confidence:", result['confidence'])
# Out:
# Claim:
#  Method 3 (Sedenion Spectral Relativity): is the sigma-metric geodesic to true d an outlier?
# Confidence: OPEN

# %% [markdown]
# ## Engine Output

# %%
import pprint
pprint.pprint({k: v for k, v in result.items()
               if k not in ('claim', 'confidence', 'latex')}, width=100, depth=3)
# Out:
# {'chance_baseline': 50.0,
#  'interpretation_caveat': 'g(sigma) here reuses the SHAPE of the wiki/34 sigma-face metric applied '
#                           'to the Horner-hash sigma address, not the same sigma variable wiki/34 '
#                           'defines. See sigma_face_metric() docstring for the exact '
#                           'reinterpretation made.',
#  'mean_percentile_rank': 38.82,
#  'per_key': [{'d': 103,
#               'e': 7,
#               'geodesic_dist_control_mean': 1.9588,
#               'geodesic_dist_true_d': 2.9234,
#               'n': 143,
#               'sigma_d_true': 0.406298,
#               'sigma_e': 0.001376,
#               'sigma_n': 0.412718,
#               'true_d_percentile_vs_controls': 13.79},
#              {'d': 63,
#               'e': 7,
#               'geodesic_dist_control_mean': 2.4044,
#               'geodesic_dist_true_d': 1.7836,
#               'n': 253,
#               'sigma_d_true': 0.048609,
#               'sigma_e': 0.001376,
#               'sigma_n': 0.546622,
#               'true_d_percentile_vs_controls': 72.73},
#              {'d': 43,
#               'e': 7,
#               'geodesic_dist_control_mean': 1.7184,
#               'geodesic_dist_true_d': 1.7442,
#               'n': 77,
#               'sigma_d_true': 0.04494,
#               'sigma_e': 0.001376,
#               'sigma_n': 0.050443,
#               'true_d_percentile_vs_controls': 15.38},
#              {'d': 2753,
#               'e': 17,
#               'geodesic_dist_control_mean': 1.5011,
#               'geodesic_dist_true_d': 1.5346,
#               'n': 3233,
#               'sigma_d_true': 0.707582,
#               'sigma_e': 0.039743,
#               'sigma_n': 0.095384,
#               'true_d_percentile_vs_controls': 44.0},
#              {'d': 8743,
#               'e': 7,
#               'geodesic_dist_control_mean': 3.1389,
#               'geodesic_dist_true_d': 2.5328,
#               'n': 10403,
#               'sigma_d_true': 0.208346,
#               'sigma_e': 0.001376,
#               'sigma_n': 0.027667,
#               'true_d_percentile_vs_controls': 85.0},
#              {'d': 5069,
#               'e': 5,
#               'geodesic_dist_control_mean': 3.1558,
#               'geodesic_dist_true_d': 4.6702,
#               'n': 8633,
#               'sigma_d_true': 0.968053,
#               'sigma_e': 0.001376,
#               'sigma_n': 0.049679,
#               'true_d_percentile_vs_controls': 2.0}],
#  'verdict': 'AT CHANCE — no evidence this mechanism recovers d'}

# %% [markdown]
# ## Mathematical Foundation
#
# $$\text{LaTeX: }\quad g(\sigma),\;\text{dist}=\textstyle\int_{\sigma_e}^{\sigma_d}g\,d\sigma$$

# %%
fig, ax = plt.subplots(figsize=(10, 5))
rows = result['per_key']
ns = [str(row['n']) for row in rows]
true_d = [row['geodesic_dist_true_d'] for row in rows]
ctrl_d = [row['geodesic_dist_control_mean'] for row in rows]
x = np.arange(len(ns)); w = 0.35
ax.bar(x - w/2, true_d, w, label='geodesic dist e → true d', color='#1ABC9C', alpha=0.85)
ax.bar(x + w/2, ctrl_d, w, label='mean geodesic dist e → control d\'', color='steelblue', alpha=0.85)
ax.set_xticks(x); ax.set_xticklabels(ns); ax.set_xlabel('n')
ax.set_title(f"Method 3 (Sedenion Spectral Relativity): {result['verdict']}")
ax.legend(fontsize=8); ax.grid(alpha=0.3)
plt.tight_layout(); plt.show()
print('Mean percentile rank vs chance(50):', result['mean_percentile_rank'])
print(result['interpretation_caveat'])
# Out:
# Mean percentile rank vs chance(50): 38.82
# g(sigma) here reuses the SHAPE of the wiki/34 sigma-face metric applied to the Horner-hash sigma address, not the same sigma variable wiki/34 defines. See sigma_face_metric() docstring for the exact reinterpretation made.

# %% [markdown]
# ## Ainulindale Reading
#
# **Confidence:** `{}'.format(result.get('confidence',''))`
#
# Run `result.keys()` to explore the full engine output.

# %%
print('Engine keys:', list(result.keys()))
# Out:
# Engine keys: ['claim', 'per_key', 'mean_percentile_rank', 'chance_baseline', 'verdict', 'confidence', 'interpretation_caveat']
