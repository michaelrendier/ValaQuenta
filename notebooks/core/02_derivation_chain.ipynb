# %% [markdown]
# # Engine: Derivation Chain — Tiers 1–5
#
# **Claim:** Every major structure in physics drops out of H_hat_RB as a facet projection. Nothing is added by hand.
#
# ```
# Tier 1 — Riemann = Fermat        R̂† = B̂ (two Euler products, same object)
# Tier 2 — What Drops Out          Yang-Mills gap, BK, Noether, NS, Langlands, BSD
# Tier 3 — H_RB Emergence          the operator is what remains
# Tier 4 — Geometric Observer      ∂̂_{∂M} IS a Hamiltonian
# Tier 5 — ln Natural Unit         ln = Hubble constant of ℕ
# ```
#
# **File:** `ValaQuenta/modules/derivation_chain/maths.py`

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../../..'))
from ValaQuenta.modules.derivation_chain import maths as dc
import math
print('derivation_chain module loaded')

# %% [markdown]
# ## Tier 1 — Riemann = Fermat

# %%
r = dc.riemann_equals_fermat()
print(f"Claim:  {r['claim']}")
print(f"Red Euler product (σ=½):  {r['red_euler_product']:.8f}")
print(f"Blue Euler product (σ=½): {r['blue_euler_product']:.8f}")
print(f"Adjoint gap: {r['adjoint_gap']:.2e}")
print(f"Confidence: {r['confidence']}")

# %% [markdown]
# ## Tier 2 — Yang-Mills Mass Gap Drop-Out

# %%
r = dc.yang_mills_dropout()
print(f"Claim:  {r['claim']}")
print(f"δ = OMEGA_ZS − d*·ln(10) = {r['gap']:.8f}")
print(f"d*·ln(10) = {r['d_star_ln10']:.8f}")
print(f"OMEGA_ZS  = {r['omega_zs']:.8f}")
print(f"Confidence: {r['confidence']}")

# %% [markdown]
# ## Tier 2 — Noether Drop-Out

# %%
r = dc.noether_dropout()
print(f"Claim:  {r['claim']}")
print(f"J_R + J_G + J_B = {r['current_sum']:.6f}  (at σ=½)")
print(f"Balance: {r['balance_status']}")
print(f"Confidence: {r['confidence']}")

# %% [markdown]
# ## Tier 3 — H_RB Emergence

# %%
r = dc.h_rb_emergence()
print(f"Claim:  {r['claim']}")
print(f"H_hat_RB form: {r['operator_form']}")
print(f"Self-adjoint:  {r['self_adjoint']}")
print(f"Confidence: {r['confidence']}")

# %% [markdown]
# ## Tier 5 — ln as Natural Unit

# %%
r = dc.ln_natural_unit()
print(f"Claim:  {r['claim']}")
print(f"ln = Hubble constant of ℕ: {r['hubble_analogy']}")
print(f"de Sitter time unit: {r['de_sitter_unit']}")
print(f"Confidence: {r['confidence']}")

# %% [markdown]
# ## Full Derivation Chain

# %%
chain = dc.full_derivation_chain()
for tier_key in sorted(chain.keys()):
    if tier_key.startswith('tier'):
        t = chain[tier_key]
        print(f"\n{tier_key.upper()}: {t.get('name', '')}")
        print(f"  Confidence: {t.get('confidence', '?')}")
        claims = t.get('claims', [])
        for c in claims[:2]:
            print(f"  - {c}")
