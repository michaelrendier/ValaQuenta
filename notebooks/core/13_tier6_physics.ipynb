# %% [markdown]
# # Engine: Tier 6 — Full Physics
#
# **Claim:** The four arithmetic operations emerge from two algebraic structures. Mathematics is not invented — it is derived.
#
# ```
# Zero Divisors (Sedenion)  =  ADDITION
# CD Tower                  =  SUBTRACTION
# Through both:                MULTIPLICATION + DIVISION
# Voilà: Mathematics.
# ```
#
# Engines in this module:
# ```
# sedenion_arithmetic()      Zero-div=+, CD=-  → ×÷ = Mathematics
# quantum_mechanics()        Full QM from H_RB at σ=½
# standard_model()           Full Standard Model Lagrangian (term-for-term)
# dirac_equation()           Relativistic QM — Dirac sea, antimatter, spin
# gauge_unification()        U(1)×SU(2)×SU(3) from ℂ×ℍ×𝕆 (Dixon 1994)
# higgs_mechanism()          SSB = Sombrero at electroweak scale
# particle_spectrum()        All 17 SM particles from 16 sedenion strata
# feynman_path_integral()    Σ paths e^{iS/ħ} from BK action
# ```
#
# **File:** `ValaQuenta/modules/tier6_physics/maths.py`

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../../..'))
from ValaQuenta.modules.tier6_physics import maths as t6
import math
print('tier6_physics module loaded')
print(f'OMEGA_ZS = {t6.OMEGA_ZS}')
print(f'D_STAR   = {t6.D_STAR}')
print(f'ALPHA    = {t6.ALPHA:.10f}  (fine structure constant)')

# %%
def _show(obj, indent=0):
    """Print whatever the engine actually returned, without assuming a schema."""
    pad = ' ' * indent
    if isinstance(obj, dict):
        width = max((len(str(k)) for k in obj), default=0)
        for k, v in obj.items():
            if isinstance(v, (dict, list, tuple)) and v:
                print(f'{pad}{str(k):>{width}} :')
                _show(v, indent + width + 3)
            else:
                print(f'{pad}{str(k):>{width}} : {v!r}')
    elif isinstance(obj, (list, tuple)):
        for j, v in enumerate(obj[:12]):
            if isinstance(v, (dict, list, tuple)) and v:
                print(f'{pad}[{j}]')
                _show(v, indent + 3)
            else:
                print(f'{pad}[{j}] {v!r}')
        if len(obj) > 12:
            print(f'{pad}... +{len(obj)-12} more')
    else:
        print(f'{pad}{obj!r}')

# %% [markdown]
# ## Sedenion Arithmetic — Four Operations from Two Structures

# %%
r = t6.sedenion_arithmetic()
print(f"Claim: {r['claim']}")
print(f"\nZero divisors found: {r['zero_divisors_found']}")
print(f"Count: {r['n_zero_divisors']}")
print(f"Note:  {r['zero_div_note']}")
print(f"\nNorm test: {r['norm_test']}")
print(f"\nArithmetic emergence:")
for op, desc in r['arithmetic'].items():
    print(f'  {op}: {desc}')
print(f"\nConclusion: {r['conclusion']}")

# %% [markdown]
# ## Quantum Mechanics from H_RB at σ=½

# %%
# Regenerated 2026-07-28: this cell indexed keys from an older
# schema. It now prints what the engine actually returns.
r = t6.quantum_mechanics()
_show(r)

# %% [markdown]
# ## Standard Model Lagrangian — Term for Term

# %%
# Regenerated 2026-07-28: this cell indexed keys from an older
# schema. It now prints what the engine actually returns.
r = t6.standard_model()
_show(r)

# %% [markdown]
# ## Particle Spectrum — 17 SM Particles from 16 Sedenion Strata

# %%
# Regenerated 2026-07-28: this cell indexed keys from an older
# schema. It now prints what the engine actually returns.
r = t6.particle_spectrum()
_show(r)

# %% [markdown]
# ## Full Physics — All 8 Engines

# %%
r = t6.full_physics()
for engine_name in ['sedenion_arithmetic','quantum_mechanics','standard_model',
                    'dirac_equation','gauge_unification','higgs_mechanism',
                    'particle_spectrum','feynman_path_integral']:
    if engine_name in r:
        conf = r[engine_name].get('confidence','?')
        claim = r[engine_name].get('claim','')[:60]
        print(f'  {engine_name:25s}  [{conf:14s}]  {claim}...')
